# %% [markdown]
# Playground for Exploratory Data Analysis

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Compare old and new RULA scores 
old_right_stringer = pd.read_excel(r"C:\Users\anand\Desktop\Old RULA Summary Statistics\right_stringer_data.xlsx")/100
old_right_camel_hump = pd.read_excel(r"C:\Users\anand\Desktop\Old RULA Summary Statistics\right_camel_hump_data.xlsx")/100
old_left_stringer = pd.read_excel(r"C:\Users\anand\Desktop\Old RULA Summary Statistics\left_stringer_data.xlsx")/100
old_left_camel_hump = pd.read_excel(r"C:\Users\anand\Desktop\Old RULA Summary Statistics\left_camel_hump_data.xlsx")/100

new_right_stringer = pd.read_excel(r"C:\Users\anand\Desktop\RULA Predictor Summary Statistics\right_stringer_data.xlsx")
new_right_camel_hump = pd.read_excel(r"C:\Users\anand\Desktop\RULA Predictor Summary Statistics\right_camel_hump_data.xlsx")
new_left_stringer = pd.read_excel(r"C:\Users\anand\Desktop\RULA Predictor Summary Statistics\left_stringer_data.xlsx")
new_left_camel_hump = pd.read_excel(r"C:\Users\anand\Desktop\RULA Predictor Summary Statistics\left_camel_hump_data.xlsx")

old_correct_right_stringer = old_right_stringer['Accuracy']
old_incorrect_by_one_right_stringer = old_right_stringer['True Medium Predicted Low']+old_right_stringer['True High Predicted Medium']+old_right_stringer['True Low Predicted Medium']+old_right_stringer['True Medium Predicted High']
old_incorrect_by_two_right_stringer = old_right_stringer['True High Predicted Low']+old_right_stringer['True Low Predicted High']

new_correct_right_stringer = new_right_stringer['Accuracy']
new_incorrect_by_one_right_stringer = new_right_stringer['True Medium Predicted Low']+new_right_stringer['True High Predicted Medium']+new_right_stringer['True Low Predicted Medium']+new_right_stringer['True Medium Predicted High']
new_incorrect_by_two_right_stringer = new_right_stringer['True High Predicted Low']+new_right_stringer['True Low Predicted High']

right_stringer_accuracy_diff_7_participants = np.mean(new_correct_right_stringer[:7])-np.mean(old_correct_right_stringer)
right_stringer_accuracy_diff_all_participants = np.mean(new_correct_right_stringer)-np.mean(old_correct_right_stringer)
right_stringer_incorrect_by_one_diff_7_participants = np.mean(new_incorrect_by_one_right_stringer[:7])-np.mean(old_incorrect_by_one_right_stringer)
right_stringer_incorrect_by_one_diff_all_participants = np.mean(new_incorrect_by_one_right_stringer)-np.mean(old_incorrect_by_one_right_stringer)
right_stringer_incorrect_by_two_diff_7_participants = np.mean(new_incorrect_by_two_right_stringer[:7])-np.mean(old_incorrect_by_two_right_stringer)
right_stringer_incorrect_by_two_diff_all_participants = np.mean(new_incorrect_by_two_right_stringer)-np.mean(old_incorrect_by_two_right_stringer)

old_correct_right_camel_hump = old_right_camel_hump['Accuracy']
old_incorrect_by_one_right_camel_hump = old_right_camel_hump['True Medium Predicted Low']+old_right_camel_hump['True High Predicted Medium']+old_right_camel_hump['True Low Predicted Medium']+old_right_camel_hump['True Medium Predicted High']
old_incorrect_by_two_right_camel_hump = old_right_camel_hump['True High Predicted Low']+old_right_camel_hump['True Low Predicted High']

new_correct_right_camel_hump = new_right_camel_hump['Accuracy']
new_incorrect_by_one_right_camel_hump = new_right_camel_hump['True Medium Predicted Low']+new_right_camel_hump['True High Predicted Medium']+new_right_camel_hump['True Low Predicted Medium']+new_right_camel_hump['True Medium Predicted High']
new_incorrect_by_two_right_camel_hump = new_right_camel_hump['True High Predicted Low']+new_right_camel_hump['True Low Predicted High']

right_camel_hump_accuracy_diff_7_participants = np.mean(new_correct_right_camel_hump[:7])-np.mean(old_correct_right_camel_hump)
right_camel_hump_accuracy_diff_all_participants = np.mean(new_correct_right_camel_hump)-np.mean(old_correct_right_camel_hump)
right_camel_hump_incorrect_by_one_diff_7_participants = np.mean(new_incorrect_by_one_right_camel_hump[:7])-np.mean(old_incorrect_by_one_right_camel_hump)
right_camel_hump_incorrect_by_one_diff_all_participants = np.mean(new_incorrect_by_one_right_camel_hump)-np.mean(old_incorrect_by_one_right_camel_hump)
right_camel_hump_incorrect_by_two_diff_7_participants = np.mean(new_incorrect_by_two_right_camel_hump[:7])-np.mean(old_incorrect_by_two_right_camel_hump)
right_camel_hump_incorrect_by_two_diff_all_participants = np.mean(new_incorrect_by_two_right_camel_hump)-np.mean(old_incorrect_by_two_right_camel_hump)

old_correct_left_stringer = old_left_stringer['Accuracy']
old_incorrect_by_one_left_stringer = old_left_stringer['True Medium Predicted Low']+old_left_stringer['True High Predicted Medium']+old_left_stringer['True Low Predicted Medium']+old_left_stringer['True Medium Predicted High']
old_incorrect_by_two_left_stringer = old_left_stringer['True High Predicted Low']+old_left_stringer['True Low Predicted High']

new_correct_left_stringer = new_left_stringer['Accuracy']
new_incorrect_by_one_left_stringer = new_left_stringer['True Medium Predicted Low']+new_left_stringer['True High Predicted Medium']+new_left_stringer['True Low Predicted Medium']+new_left_stringer['True Medium Predicted High']
new_incorrect_by_two_left_stringer = new_left_stringer['True High Predicted Low']+new_left_stringer['True Low Predicted High']

left_stringer_accuracy_diff_7_participants = np.mean(new_correct_left_stringer[:7])-np.mean(old_correct_left_stringer)
left_stringer_accuracy_diff_all_participants = np.mean(new_correct_left_stringer)-np.mean(old_correct_left_stringer)
left_stringer_incorrect_by_one_diff_7_participants = np.mean(new_incorrect_by_one_left_stringer[:7])-np.mean(old_incorrect_by_one_left_stringer)
left_stringer_incorrect_by_one_diff_all_participants = np.mean(new_incorrect_by_one_left_stringer)-np.mean(old_incorrect_by_one_left_stringer)
left_stringer_incorrect_by_two_diff_7_participants = np.mean(new_incorrect_by_two_left_stringer[:7])-np.mean(old_incorrect_by_two_left_stringer)
left_stringer_incorrect_by_two_diff_all_participants = np.mean(new_incorrect_by_two_left_stringer)-np.mean(old_incorrect_by_two_left_stringer)

old_correct_left_camel_hump = old_left_camel_hump['Accuracy']
old_incorrect_by_one_left_camel_hump = old_left_camel_hump['True Medium Predicted Low']+old_left_camel_hump['True High Predicted Medium']+old_left_camel_hump['True Low Predicted Medium']+old_left_camel_hump['True Medium Predicted High']
old_incorrect_by_two_left_camel_hump = old_left_camel_hump['True High Predicted Low']+old_left_camel_hump['True Low Predicted High']

new_correct_left_camel_hump = new_left_camel_hump['Accuracy']
new_incorrect_by_one_left_camel_hump = new_left_camel_hump['True Medium Predicted Low']+new_left_camel_hump['True High Predicted Medium']+new_left_camel_hump['True Low Predicted Medium']+new_left_camel_hump['True Medium Predicted High']
new_incorrect_by_two_left_camel_hump = new_left_camel_hump['True High Predicted Low']+new_left_camel_hump['True Low Predicted High']

left_camel_hump_accuracy_diff_7_participants = np.mean(new_correct_left_camel_hump[:7])-np.mean(old_correct_left_camel_hump)
left_camel_hump_accuracy_diff_all_participants = np.mean(new_correct_left_camel_hump)-np.mean(old_correct_left_camel_hump)
left_camel_hump_incorrect_by_one_diff_7_participants = np.mean(new_incorrect_by_one_left_camel_hump[:7])-np.mean(old_incorrect_by_one_left_camel_hump)
left_camel_hump_incorrect_by_one_diff_all_participants = np.mean(new_incorrect_by_one_left_camel_hump)-np.mean(old_incorrect_by_one_left_camel_hump)
left_camel_hump_incorrect_by_two_diff_7_participants = np.mean(new_incorrect_by_two_left_camel_hump[:7])-np.mean(old_incorrect_by_two_left_camel_hump)
left_camel_hump_incorrect_by_two_diff_all_participants = np.mean(new_incorrect_by_two_left_camel_hump)-np.mean(old_incorrect_by_two_left_camel_hump)

# %%
# Accuracy across participants 
# For 7 participants
old_correct_left = (old_correct_left_stringer[:7]+old_correct_left_camel_hump[:7])/2
old_correct_right = (old_correct_right_stringer[:7]+old_correct_right_camel_hump[:7])/2
old_correct = (old_correct_left+old_correct_right)/2
old_incorrect_by_one_left = (old_incorrect_by_one_left_stringer[:7]+old_incorrect_by_one_left_camel_hump[:7])/2
old_incorrect_by_one_right = (old_incorrect_by_one_right_stringer[:7]+old_incorrect_by_one_right_camel_hump[:7])/2
old_incorrect_by_one = (old_incorrect_by_one_left+old_incorrect_by_one_right)/2
old_incorrect_by_two_left = (old_incorrect_by_two_left_stringer[:7]+old_incorrect_by_two_left_camel_hump[:7])/2
old_incorrect_by_two_right = (old_incorrect_by_two_right_stringer[:7]+old_incorrect_by_two_right_camel_hump[:7])/2
old_incorrect_by_two = (old_incorrect_by_two_left+old_incorrect_by_two_right)/2

new_correct_left = (new_correct_left_stringer[:7]+new_correct_left_camel_hump[:7])/2
new_correct_right = (new_correct_right_stringer[:7]+new_correct_right_camel_hump[:7])/2
new_correct = (new_correct_left+new_correct_right)/2
new_incorrect_by_one_left = (new_incorrect_by_one_left_stringer[:7]+new_incorrect_by_one_left_camel_hump[:7])/2
new_incorrect_by_one_right = (new_incorrect_by_one_right_stringer[:7]+new_incorrect_by_one_right_camel_hump[:7])/2
new_incorrect_by_one = (new_incorrect_by_one_left+new_incorrect_by_one_right)/2
new_incorrect_by_two_left = (new_incorrect_by_two_left_stringer[:7]+new_incorrect_by_two_left_camel_hump[:7])/2
new_incorrect_by_two_right = (new_incorrect_by_two_right_stringer[:7]+new_incorrect_by_two_right_camel_hump[:7])/2
new_incorrect_by_two = (new_incorrect_by_two_left+new_incorrect_by_two_right)/2




bar_width = 0.2
indices = np.arange(7)

fig, axs = plt.subplots(1, 1, figsize=(14,2))

axs.bar(indices, new_correct[:7]-old_correct[:7], bar_width, color='green',edgecolor='black',label = 'Correctly Classified')
axs.bar(indices+bar_width, -(new_incorrect_by_one[:7]-old_incorrect_by_one[:7]), bar_width, color='#d4aa00', alpha = 0.7,edgecolor='black',label = 'Incorrectly Classified by One')
axs.bar(indices+2*bar_width, -(new_incorrect_by_two[:7]-old_incorrect_by_two[:7]), bar_width, color='#ff9999',alpha = 0.8,edgecolor='black',label = 'Incorrectly Classified by Two')

axs.set_title('Improvement from old RULA predictors')
axs.set_yticks([-0.2,-0.1, 0, 0.1,0.2])
axs.set_xticks(indices+bar_width)
axs.grid(axis='y')
axs.set_xticklabels(['P1', 'P2', 'P3', 'P4', 'P5', 'P6', 'P7'])
axs.set_ylabel('Fraction of Data')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
# Out:
# Text(0, 0.5, 'Fraction of Data')

# %%
bar_width = 0.2


# Plot 12 bars, 3 for each hand and tool combination
# First 3 bars are stringer accuracy diff,stringer incorrect by one diff, stringer incorrect by two diff
# Next 3 bars are camel hump accuracy diff, camel hump incorrect by one diff, camel hump incorrect by two diff
# For 7 participants
fig, axs = plt.subplots(1, 1, figsize=(7,2))

axs.bar(0, right_stringer_accuracy_diff_7_participants, bar_width, color='green',alpha = 0.8, edgecolor='black')
axs.bar(0+bar_width, -right_stringer_incorrect_by_one_diff_7_participants, bar_width, color='#d4aa00', alpha = 0.6,edgecolor='black')
axs.bar(0+2*bar_width, -right_stringer_incorrect_by_two_diff_7_participants, bar_width, color='#ff9999',alpha = 0.8,edgecolor='black')

axs.bar(1, right_camel_hump_accuracy_diff_7_participants, bar_width, color='green',alpha = 0.8,edgecolor='black')
axs.bar(1+bar_width, -right_camel_hump_incorrect_by_one_diff_7_participants, bar_width, color='#d4aa00',alpha = 0.6,edgecolor='black')
axs.bar(1+2*bar_width, -right_camel_hump_incorrect_by_two_diff_7_participants, bar_width, color='#ff9999',alpha = 0.8,edgecolor='black')

axs.bar(2, left_stringer_accuracy_diff_7_participants, bar_width, color='green',alpha = 0.8,edgecolor='black')
axs.bar(2+bar_width, -left_stringer_incorrect_by_one_diff_7_participants, bar_width, color='#d4aa00',alpha = 0.6,edgecolor='black')
axs.bar(2+2*bar_width, -left_stringer_incorrect_by_two_diff_7_participants, bar_width, color='#ff9999',alpha = 0.8,edgecolor='black')

axs.bar(3, left_camel_hump_accuracy_diff_7_participants, bar_width, color='green',alpha = 0.8,edgecolor='black')
axs.bar(3+bar_width, -left_camel_hump_incorrect_by_one_diff_7_participants, bar_width, color='#d4aa00',alpha = 0.6,edgecolor='black')
axs.bar(3+2*bar_width, -left_camel_hump_incorrect_by_two_diff_7_participants, bar_width, color='#ff9999',alpha = 0.8,edgecolor='black')
axs.set_title('Percentage improvement from previous RULA predictor\n(7 Participants)')

axs.set_yticks([0,0.025,0.05,0.075])
# Set y tick labels as percentage
y_vals = axs.get_yticks()
axs.set_yticklabels(['{:,.0%}'.format(x) for x in y_vals])
axs.set_xticks([0.2,1.2,2.2,3.2])
axs.grid(axis='y')
axs.set_xticklabels(['Right Hand,\nStringer', 'Right Hand, \nConvex Mould', 'Left Hand,\nStringer', 'Left Hand,\nConvex Mould'])
axs.set_ylabel('Percentage Improvement')
plt.legend(['Correctly Classified', 'Incorrectly Classified by One', 'Incorrectly Classified by Two'],bbox_to_anchor=(1.5, 0.7), loc='upper right', borderaxespad=0.)
# plt.show()
plt.savefig(r'C:\Users\anand\Desktop\ergo paper figures\improvement_from_old_rula_predictor_7_participants.svg', format='svg', dpi=1200, bbox_inches = 'tight')
# save as eps

# %%
# For all participants
fig, axs = plt.subplots(1, 1, figsize=(7,2))

axs.bar(0, right_stringer_accuracy_diff_all_participants, bar_width, color='green',edgecolor='black')
axs.bar(0+bar_width, right_stringer_incorrect_by_one_diff_all_participants, bar_width, color='#d4aa00', alpha = 0.7,edgecolor='black')
axs.bar(0+2*bar_width, right_stringer_incorrect_by_two_diff_all_participants, bar_width, color='#ff9999',alpha = 0.8,edgecolor='black')

axs.bar(1, right_camel_hump_accuracy_diff_all_participants, bar_width, color='green',edgecolor='black')
axs.bar(1+bar_width, right_camel_hump_incorrect_by_one_diff_all_participants, bar_width, color='#d4aa00',alpha = 0.7,edgecolor='black')
axs.bar(1+2*bar_width, right_camel_hump_incorrect_by_two_diff_all_participants, bar_width, color='#ff9999',alpha = 0.8,edgecolor='black')

axs.bar(2, left_stringer_accuracy_diff_all_participants, bar_width, color='green',edgecolor='black')
axs.bar(2+bar_width, left_stringer_incorrect_by_one_diff_all_participants, bar_width, color='#d4aa00',alpha = 0.7,edgecolor='black')
axs.bar(2+2*bar_width, left_stringer_incorrect_by_two_diff_all_participants, bar_width, color='#ff9999',alpha = 0.8,edgecolor='black')

axs.bar(3, left_camel_hump_accuracy_diff_all_participants, bar_width, color='green',edgecolor='black')
axs.bar(3+bar_width, left_camel_hump_incorrect_by_one_diff_all_participants, bar_width, color='#d4aa00',alpha = 0.7,edgecolor='black')
axs.bar(3+2*bar_width, left_camel_hump_incorrect_by_two_diff_all_participants, bar_width, color='#ff9999',alpha = 0.8,edgecolor='black')

axs.set_title('Delta between new and old RULA predictors\n(All Participants)')
axs.set_yticks([-0.05, 0, 0.05, 0.08])
axs.set_xticks([0.2,1.2,2.2,3.2])
axs.grid(axis='y')
axs.set_xticklabels(['Right Hand,\nStringer', 'Right Hand, \nConvex Mould', 'Left Hand,\nStringer', 'Left Hand,\nConvex Mould'])
axs.set_ylabel('Change in Accuracy/Error Rate')
plt.show()

# %%
# Compare old and new HAL scores 
old_right_stringer = pd.read_excel(r"C:\Users\anand\Desktop\Old HAL Summary Statistics\right_stringer_data.xlsx")/100
old_right_camel_hump = pd.read_excel(r"C:\Users\anand\Desktop\Old HAL Summary Statistics\right_camel_hump_data.xlsx")/100
old_left_stringer = pd.read_excel(r"C:\Users\anand\Desktop\Old HAL Summary Statistics\left_stringer_data.xlsx")/100
old_left_camel_hump = pd.read_excel(r"C:\Users\anand\Desktop\Old HAL Summary Statistics\left_camel_hump_data.xlsx")/100

new_right_stringer = pd.read_excel(r"C:\Users\anand\Desktop\HAL Predictor Summary Statistics\right_stringer_data.xlsx")
new_right_camel_hump = pd.read_excel(r"C:\Users\anand\Desktop\HAL Predictor Summary Statistics\right_camel_hump_data.xlsx")
new_left_stringer = pd.read_excel(r"C:\Users\anand\Desktop\HAL Predictor Summary Statistics\left_stringer_data.xlsx")
new_left_camel_hump = pd.read_excel(r"C:\Users\anand\Desktop\HAL Predictor Summary Statistics\left_camel_hump_data.xlsx")

old_correct_right_stringer = old_right_stringer['Accuracy']
old_incorrect_by_one_right_stringer = old_right_stringer['True Medium Predicted Low']+old_right_stringer['True High Predicted Medium']+old_right_stringer['True Low Predicted Medium']+old_right_stringer['True Medium Predicted High']
old_incorrect_by_two_right_stringer = old_right_stringer['True High Predicted Low']+old_right_stringer['True Low Predicted High']

new_correct_right_stringer = new_right_stringer['Accuracy']
new_incorrect_by_one_right_stringer = new_right_stringer['True Medium Predicted Low']+new_right_stringer['True High Predicted Medium']+new_right_stringer['True Low Predicted Medium']+new_right_stringer['True Medium Predicted High']
new_incorrect_by_two_right_stringer = new_right_stringer['True High Predicted Low']+new_right_stringer['True Low Predicted High']

right_stringer_accuracy_diff_7_participants = np.mean(new_correct_right_stringer[:7])-np.mean(old_correct_right_stringer)
right_stringer_accuracy_diff_all_participants = np.mean(new_correct_right_stringer)-np.mean(old_correct_right_stringer)
right_stringer_incorrect_by_one_diff_7_participants = np.mean(new_incorrect_by_one_right_stringer[:7])-np.mean(old_incorrect_by_one_right_stringer)
right_stringer_incorrect_by_one_diff_all_participants = np.mean(new_incorrect_by_one_right_stringer)-np.mean(old_incorrect_by_one_right_stringer)
right_stringer_incorrect_by_two_diff_7_participants = np.mean(new_incorrect_by_two_right_stringer[:7])-np.mean(old_incorrect_by_two_right_stringer)
right_stringer_incorrect_by_two_diff_all_participants = np.mean(new_incorrect_by_two_right_stringer)-np.mean(old_incorrect_by_two_right_stringer)

old_correct_right_camel_hump = old_right_camel_hump['Accuracy']
old_incorrect_by_one_right_camel_hump = old_right_camel_hump['True Medium Predicted Low']+old_right_camel_hump['True High Predicted Medium']+old_right_camel_hump['True Low Predicted Medium']+old_right_camel_hump['True Medium Predicted High']
old_incorrect_by_two_right_camel_hump = old_right_camel_hump['True High Predicted Low']+old_right_camel_hump['True Low Predicted High']

new_correct_right_camel_hump = new_right_camel_hump['Accuracy']
new_incorrect_by_one_right_camel_hump = new_right_camel_hump['True Medium Predicted Low']+new_right_camel_hump['True High Predicted Medium']+new_right_camel_hump['True Low Predicted Medium']+new_right_camel_hump['True Medium Predicted High']
new_incorrect_by_two_right_camel_hump = new_right_camel_hump['True High Predicted Low']+new_right_camel_hump['True Low Predicted High']

right_camel_hump_accuracy_diff_7_participants = np.mean(new_correct_right_camel_hump[:7])-np.mean(old_correct_right_camel_hump)
right_camel_hump_accuracy_diff_all_participants = np.mean(new_correct_right_camel_hump)-np.mean(old_correct_right_camel_hump)
right_camel_hump_incorrect_by_one_diff_7_participants = np.mean(new_incorrect_by_one_right_camel_hump[:7])-np.mean(old_incorrect_by_one_right_camel_hump)
right_camel_hump_incorrect_by_one_diff_all_participants = np.mean(new_incorrect_by_one_right_camel_hump)-np.mean(old_incorrect_by_one_right_camel_hump)
right_camel_hump_incorrect_by_two_diff_7_participants = np.mean(new_incorrect_by_two_right_camel_hump[:7])-np.mean(old_incorrect_by_two_right_camel_hump)
right_camel_hump_incorrect_by_two_diff_all_participants = np.mean(new_incorrect_by_two_right_camel_hump)-np.mean(old_incorrect_by_two_right_camel_hump)

old_correct_left_stringer = old_left_stringer['Accuracy']
old_incorrect_by_one_left_stringer = old_left_stringer['True Medium Predicted Low']+old_left_stringer['True High Predicted Medium']+old_left_stringer['True Low Predicted Medium']+old_left_stringer['True Medium Predicted High']
old_incorrect_by_two_left_stringer = old_left_stringer['True High Predicted Low']+old_left_stringer['True Low Predicted High']

new_correct_left_stringer = new_left_stringer['Accuracy']
new_incorrect_by_one_left_stringer = new_left_stringer['True Medium Predicted Low']+new_left_stringer['True High Predicted Medium']+new_left_stringer['True Low Predicted Medium']+new_left_stringer['True Medium Predicted High']
new_incorrect_by_two_left_stringer = new_left_stringer['True High Predicted Low']+new_left_stringer['True Low Predicted High']

left_stringer_accuracy_diff_7_participants = np.mean(new_correct_left_stringer[:7])-np.mean(old_correct_left_stringer)
left_stringer_accuracy_diff_all_participants = np.mean(new_correct_left_stringer)-np.mean(old_correct_left_stringer)
left_stringer_incorrect_by_one_diff_7_participants = np.mean(new_incorrect_by_one_left_stringer[:7])-np.mean(old_incorrect_by_one_left_stringer)
left_stringer_incorrect_by_one_diff_all_participants = np.mean(new_incorrect_by_one_left_stringer)-np.mean(old_incorrect_by_one_left_stringer)
left_stringer_incorrect_by_two_diff_7_participants = np.mean(new_incorrect_by_two_left_stringer[:7])-np.mean(old_incorrect_by_two_left_stringer)
left_stringer_incorrect_by_two_diff_all_participants = np.mean(new_incorrect_by_two_left_stringer)-np.mean(old_incorrect_by_two_left_stringer)

old_correct_left_camel_hump = old_left_camel_hump['Accuracy']
old_incorrect_by_one_left_camel_hump = old_left_camel_hump['True Medium Predicted Low']+old_left_camel_hump['True High Predicted Medium']+old_left_camel_hump['True Low Predicted Medium']+old_left_camel_hump['True Medium Predicted High']
old_incorrect_by_two_left_camel_hump = old_left_camel_hump['True High Predicted Low']+old_left_camel_hump['True Low Predicted High']

new_correct_left_camel_hump = new_left_camel_hump['Accuracy']
new_incorrect_by_one_left_camel_hump = new_left_camel_hump['True Medium Predicted Low']+new_left_camel_hump['True High Predicted Medium']+new_left_camel_hump['True Low Predicted Medium']+new_left_camel_hump['True Medium Predicted High']
new_incorrect_by_two_left_camel_hump = new_left_camel_hump['True High Predicted Low']+new_left_camel_hump['True Low Predicted High']

left_camel_hump_accuracy_diff_7_participants = np.mean(new_correct_left_camel_hump[:7])-np.mean(old_correct_left_camel_hump)
left_camel_hump_accuracy_diff_all_participants = np.mean(new_correct_left_camel_hump)-np.mean(old_correct_left_camel_hump)
left_camel_hump_incorrect_by_one_diff_7_participants = np.mean(new_incorrect_by_one_left_camel_hump[:7])-np.mean(old_incorrect_by_one_left_camel_hump)
left_camel_hump_incorrect_by_one_diff_all_participants = np.mean(new_incorrect_by_one_left_camel_hump)-np.mean(old_incorrect_by_one_left_camel_hump)
left_camel_hump_incorrect_by_two_diff_7_participants = np.mean(new_incorrect_by_two_left_camel_hump[:7])-np.mean(old_incorrect_by_two_left_camel_hump)
left_camel_hump_incorrect_by_two_diff_all_participants = np.mean(new_incorrect_by_two_left_camel_hump)-np.mean(old_incorrect_by_two_left_camel_hump)

# %%
# Accuracy across participants 
# For 7 participants
old_correct_left = (old_correct_left_stringer[:7]+old_correct_left_camel_hump[:7])/2
old_correct_right = (old_correct_right_stringer[:7]+old_correct_right_camel_hump[:7])/2
old_correct = (old_correct_left+old_correct_right)/2
old_incorrect_by_one_left = (old_incorrect_by_one_left_stringer[:7]+old_incorrect_by_one_left_camel_hump[:7])/2
old_incorrect_by_one_right = (old_incorrect_by_one_right_stringer[:7]+old_incorrect_by_one_right_camel_hump[:7])/2
old_incorrect_by_one = (old_incorrect_by_one_left+old_incorrect_by_one_right)/2
old_incorrect_by_two_left = (old_incorrect_by_two_left_stringer[:7]+old_incorrect_by_two_left_camel_hump[:7])/2
old_incorrect_by_two_right = (old_incorrect_by_two_right_stringer[:7]+old_incorrect_by_two_right_camel_hump[:7])/2
old_incorrect_by_two = (old_incorrect_by_two_left+old_incorrect_by_two_right)/2

new_correct_left = (new_correct_left_stringer[:7]+new_correct_left_camel_hump[:7])/2
new_correct_right = (new_correct_right_stringer[:7]+new_correct_right_camel_hump[:7])/2
new_correct = (new_correct_left+new_correct_right)/2
new_incorrect_by_one_left = (new_incorrect_by_one_left_stringer[:7]+new_incorrect_by_one_left_camel_hump[:7])/2
new_incorrect_by_one_right = (new_incorrect_by_one_right_stringer[:7]+new_incorrect_by_one_right_camel_hump[:7])/2
new_incorrect_by_one = (new_incorrect_by_one_left+new_incorrect_by_one_right)/2
new_incorrect_by_two_left = (new_incorrect_by_two_left_stringer[:7]+new_incorrect_by_two_left_camel_hump[:7])/2
new_incorrect_by_two_right = (new_incorrect_by_two_right_stringer[:7]+new_incorrect_by_two_right_camel_hump[:7])/2
new_incorrect_by_two = (new_incorrect_by_two_left+new_incorrect_by_two_right)/2




bar_width = 0.2
indices = np.arange(7)

fig, axs = plt.subplots(1, 1, figsize=(14,2))

axs.bar(indices, new_correct[:7]-old_correct[:7], bar_width, color='green',edgecolor='black',label = 'Correctly Classified')
axs.bar(indices+bar_width, new_incorrect_by_one[:7]-old_incorrect_by_one[:7], bar_width, color='#d4aa00', alpha = 0.7,edgecolor='black',label = 'Incorrectly Classified by One')
axs.bar(indices+2*bar_width, new_incorrect_by_two[:7]-old_incorrect_by_two[:7], bar_width, color='#ff9999',alpha = 0.8,edgecolor='black',label = 'Incorrectly Classified by Two')

axs.set_title('Delta between new and old HAL predictors')
axs.set_yticks([-0.2,-0.1, 0, 0.1, 0.2])

axs.set_xticks(indices+bar_width)
axs.grid(axis='y')
axs.set_xticklabels(['P1', 'P2', 'P3', 'P4', 'P5', 'P6', 'P7'])
axs.set_ylabel('Fraction of data')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
# Out:
# Text(0, 0.5, 'Fraction of data')

# %%
bar_width = 0.2


# Plot 12 bars, 3 for each hand and tool combination
# First 3 bars are stringer accuracy diff,stringer incorrect by one diff, stringer incorrect by two diff
# Next 3 bars are camel hump accuracy diff, camel hump incorrect by one diff, camel hump incorrect by two diff
# For 7 participants
fig, axs = plt.subplots(1, 1, figsize=(7,2))

axs.bar(0, right_stringer_accuracy_diff_7_participants, bar_width, color='green',alpha = 0.8, edgecolor='black')
axs.bar(0+bar_width, -right_stringer_incorrect_by_one_diff_7_participants, bar_width, color='#d4aa00', alpha = 0.6,edgecolor='black')
axs.bar(0+2*bar_width, -right_stringer_incorrect_by_two_diff_7_participants, bar_width, color='#ff9999',alpha = 0.8,edgecolor='black')

axs.bar(1, right_camel_hump_accuracy_diff_7_participants, bar_width, color='green',alpha = 0.8,edgecolor='black')
axs.bar(1+bar_width, -right_camel_hump_incorrect_by_one_diff_7_participants, bar_width, color='#d4aa00',alpha = 0.6,edgecolor='black')
axs.bar(1+2*bar_width, -right_camel_hump_incorrect_by_two_diff_7_participants, bar_width, color='#ff9999',alpha = 0.8,edgecolor='black')

axs.bar(2, left_stringer_accuracy_diff_7_participants, bar_width, color='green',alpha = 0.8,edgecolor='black')
axs.bar(2+bar_width, -left_stringer_incorrect_by_one_diff_7_participants, bar_width, color='#d4aa00',alpha = 0.6,edgecolor='black')
axs.bar(2+2*bar_width, -left_stringer_incorrect_by_two_diff_7_participants, bar_width, color='#ff9999',alpha = 0.8,edgecolor='black')

axs.bar(3, left_camel_hump_accuracy_diff_7_participants, bar_width, color='green',alpha = 0.8,edgecolor='black')
axs.bar(3+bar_width, -left_camel_hump_incorrect_by_one_diff_7_participants, bar_width, color='#d4aa00',alpha = 0.6,edgecolor='black')
axs.bar(3+2*bar_width, -left_camel_hump_incorrect_by_two_diff_7_participants, bar_width, color='#ff9999',alpha = 0.8,edgecolor='black')
axs.set_title('Percentage improvement from previous HAL predictor\n(7 Participants)')

axs.set_yticks([0,0.05,0.15,0.25])
# Set y tick labels as percentage
y_vals = axs.get_yticks()
axs.set_yticklabels(['{:,.0%}'.format(x) for x in y_vals])
axs.set_xticks([0.2,1.2,2.2,3.2])
axs.grid(axis='y')
axs.set_xticklabels(['Right Hand,\nStringer', 'Right Hand, \nConvex Mould', 'Left Hand,\nStringer', 'Left Hand,\nConvex Mould'])
axs.set_ylabel('Percentage Improvement')
plt.legend(['Correctly Classified', 'Incorrectly Classified by One', 'Incorrectly Classified by Two'],bbox_to_anchor=(1.5, 0.7), loc='upper right', borderaxespad=0.)
# plt.show()
plt.savefig(r'C:\Users\anand\Desktop\ergo paper figures\improvement_from_old_hal_predictor_7_participants.svg', format='svg', dpi=1200, bbox_inches = 'tight')

# %%
# For all participants
fig, axs = plt.subplots(1, 1, figsize=(7,2))

axs.bar(0, right_stringer_accuracy_diff_all_participants, bar_width, color='green',edgecolor='black')
axs.bar(0+bar_width, right_stringer_incorrect_by_one_diff_all_participants, bar_width, color='#d4aa00', alpha = 0.7,edgecolor='black')
axs.bar(0+2*bar_width, right_stringer_incorrect_by_two_diff_all_participants, bar_width, color='#ff9999',alpha = 0.8,edgecolor='black')

axs.bar(1, right_camel_hump_accuracy_diff_all_participants, bar_width, color='green',edgecolor='black')
axs.bar(1+bar_width, right_camel_hump_incorrect_by_one_diff_all_participants, bar_width, color='#d4aa00',alpha = 0.7,edgecolor='black')
axs.bar(1+2*bar_width, right_camel_hump_incorrect_by_two_diff_all_participants, bar_width, color='#ff9999',alpha = 0.8,edgecolor='black')

axs.bar(2, left_stringer_accuracy_diff_all_participants, bar_width, color='green',edgecolor='black')
axs.bar(2+bar_width, left_stringer_incorrect_by_one_diff_all_participants, bar_width, color='#d4aa00',alpha = 0.7,edgecolor='black')
axs.bar(2+2*bar_width, left_stringer_incorrect_by_two_diff_all_participants, bar_width, color='#ff9999',alpha = 0.8,edgecolor='black')

axs.bar(3, left_camel_hump_accuracy_diff_all_participants, bar_width, color='green',edgecolor='black')
axs.bar(3+bar_width, left_camel_hump_incorrect_by_one_diff_all_participants, bar_width, color='#d4aa00',alpha = 0.7,edgecolor='black')
axs.bar(3+2*bar_width, left_camel_hump_incorrect_by_two_diff_all_participants, bar_width, color='#ff9999',alpha = 0.8,edgecolor='black')

axs.set_title('Difference between New and Old HAL Predictor Accuracy and Error Rate\n(All Participants)')
axs.set_yticks([-0.2,-0.1, 0,0.15,0.2,0.3])
axs.set_xticks([0.2,1.2,2.2,3.2])
axs.grid(axis='y')
axs.set_xticklabels(['Right Hand,\nStringer', 'Right Hand, \nConvex Mould', 'Left Hand,\nStringer', 'Left Hand,\nConvex Mould'])
axs.set_ylabel('Change in Accuracy/Error Rate')
plt.show()
